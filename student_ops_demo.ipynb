# %% [markdown]
# <a href="https://colab.research.google.com/github/Pshah3199/student-operations-management-system/blob/main/student_ops_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# student_ops_cli.py

import csv
import os

FILENAME = "students.csv"

def add_student():
    file_exists = os.path.isfile(FILENAME)

    name = input("Enter student name: ")
    attendance = int(input("Enter attendance (%): "))
    marks = int(input("Enter marks: "))

    with open(FILENAME, "a", newline="") as file:
        writer = csv.writer(file)
        if not file_exists:
            writer.writerow(["Name", "Attendance", "Marks"])
        writer.writerow([name, attendance, marks)

    print("Student added successfully!")

def view_students():
    if not os.path.exists(FILENAME):
        print("No records found.")
        return

    with open(FILENAME, "r") as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)

def menu():
    while True:
        print("\n1. Add Student")
        print("2. View Students")
        print("3. Exit")

        choice = input("Choose option: ")

        if choice == "1":
            add_student()
        elif choice == "2":
            view_students()
        elif choice == "3":
            break
        else:
            print("Invalid choice")

menu()

# %%
# student_ops_demo.ipynb

import csv
import os

FILENAME = "students.csv"

def add_student(name, attendance, marks):
    file_exists = os.path.isfile(FILENAME)

    with open(FILENAME, "a", newline="") as file:
        writer = csv.writer(file)
        if not file_exists:
            writer.writerow(["Name", "Attendance", "Marks"])
        writer.writerow([name, attendance, marks])

def view_students():
    if not os.path.exists(FILENAME):
        print("No records found.")
        return

    with open(FILENAME, "r") as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)

# ---- DEMO RUN ----
add_student("Rahul", 85, 78)
add_student("Anita", 92, 88)
add_student("Priya", 75, 69)

print("Student Records:")
view_students()
# Out:
# Student Records:
# ['Name', 'Attendance', 'Marks']
# ['Rahul', '85', '78']
# ['Anita', '92', '88']
# ['Priya', '75', '69']

# %% [markdown]
# This notebook demonstrates the demo version of the Student Operations
# Management System. Sample student data is added programmatically to
# show how records are stored and retrieved using CSV file handling.
